# %% [markdown]
# Keras also supports a simpler interface to save both the model weights and model architecture together into a single `H5` file. Saving the model in this way includes everything we need to know about the model, including:
# - Model weights.
# - Model architecture.
# - Model compilation details (loss and metrics).
# - Model optimizer state.
# This means that we can load and use the model directly, without having to re-compile it as we did in the examples above. This is the preferred way for saving and loading your Keras model.

# %% [markdown]
# ### 1. How to Save a Keras Model

# %%
import tensorflow as tf
import pandas as pd
import os

# Check for GPU availability and enable memory growth
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    print("GPU is available. Using GPU for training.")
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
else:
    print("No GPU detected. Using CPU.")

# Load the Pima Indians Diabetes dataset
dataset = pd.read_csv('./data/diabetes.csv')
dataset.columns = ['NTP', 'PGC', 'DBP', 'TSFT', '2hSI', 'BMI', 'DPF', 'Age', 'OnDiab']

# Split into input (X) and output (Y) variables
X = dataset.drop("OnDiab", axis=1)
Y = dataset["OnDiab"]

# Define the model using tf.keras
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(12, input_dim=8, activation='relu'))
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Optionally, you can explicitly force the model to train on GPU:
with tf.device('/GPU:0'):
    model.fit(X, Y, epochs=150, batch_size=10, verbose=1)

# Evaluate the model
scores = model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1] * 100))

# Save the model and architecture to a single file
model.save("./models/model.h5")
print("Saved model to disk")
# Out:
# 2025-02-20 23:40:46.330470: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-20 23:40:46.427082: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740123646.467536   21349 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740123646.482751   21349 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-20 23:40:46.575854: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# No GPU detected. Using CPU.
# Epoch 1/150
# 2025-02-20 23:40:49.066521: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-20 23:40:49.066540: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: oem
# 2025-02-20 23:40:49.066544: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: oem
# 2025-02-20 23:40:49.066607: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 560.35.5
# 2025-02-20 23:40:49.066618: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 560.35.5
# 2025-02-20 23:40:49.066621: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 560.35.5
# /home/oem/Documents/github/magnimind_projects/magpenv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 863us/step - accuracy: 0.4070 - loss: 5.3639
# Epoch 2/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.5818 - loss: 1.7742
# Epoch 3/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.6361 - loss: 1.0336
# Epoch 4/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.6338 - loss: 0.7985
# Epoch 5/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.6485 - loss: 0.7369
# Epoch 6/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.6622 - loss: 0.7209
# Epoch 7/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.6730 - loss: 0.6780
# Epoch 8/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - accuracy: 0.6273 - loss: 0.7028
# Epoch 9/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.6733 - loss: 0.6646
# Epoch 10/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.6974 - loss: 0.6350
# Epoch 11/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.6938 - loss: 0.5898
# Epoch 12/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.6753 - loss: 0.6240
# Epoch 13/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.6641 - loss: 0.6643
# Epoch 14/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.6780 - loss: 0.6318
# Epoch 15/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.6685 - loss: 0.6380
# Epoch 16/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.6807 - loss: 0.6130
# Epoch 17/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.6867 - loss: 0.6156
# Epoch 18/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.7042 - loss: 0.5849
# Epoch 19/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.6770 - loss: 0.6160
# Epoch 20/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.6684 - loss: 0.6176
# Epoch 21/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.6568 - loss: 0.6534
# Epoch 22/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7133 - loss: 0.5781
# Epoch 23/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.6723 - loss: 0.6251
# Epoch 24/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.6925 - loss: 0.5797
# Epoch 25/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.6624 - loss: 0.6075
# Epoch 26/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.7044 - loss: 0.5651
# Epoch 27/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.6998 - loss: 0.5835
# Epoch 28/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.6827 - loss: 0.5931
# Epoch 29/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.7156 - loss: 0.5750
# Epoch 30/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.7081 - loss: 0.5867
# Epoch 31/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.7159 - loss: 0.5638
# Epoch 32/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.6754 - loss: 0.5837
# Epoch 33/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.7241 - loss: 0.5367
# Epoch 34/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.7316 - loss: 0.5629
# Epoch 35/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.7309 - loss: 0.5466
# Epoch 36/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.6984 - loss: 0.5628
# Epoch 37/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.7465 - loss: 0.5289
# Epoch 38/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.6977 - loss: 0.5870
# Epoch 39/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.6959 - loss: 0.5720
# Epoch 40/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.7395 - loss: 0.5628
# Epoch 41/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.6909 - loss: 0.5765
# Epoch 42/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.7189 - loss: 0.5434
# Epoch 43/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7454 - loss: 0.5439
# Epoch 44/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.7475 - loss: 0.5332
# Epoch 45/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.6892 - loss: 0.5691
# Epoch 46/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7234 - loss: 0.5374
# Epoch 47/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7452 - loss: 0.5338
# Epoch 48/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.7641 - loss: 0.5200
# Epoch 49/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.7339 - loss: 0.5446
# Epoch 50/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.7258 - loss: 0.5326
# Epoch 51/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.7245 - loss: 0.5705
# Epoch 52/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.7396 - loss: 0.5415
# Epoch 53/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.7146 - loss: 0.5829
# Epoch 54/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.7211 - loss: 0.5339
# Epoch 55/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.7125 - loss: 0.5638
# Epoch 56/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.7512 - loss: 0.5115
# Epoch 57/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.7335 - loss: 0.5188
# Epoch 58/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7480 - loss: 0.5227
# Epoch 59/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7431 - loss: 0.5320
# Epoch 60/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.7490 - loss: 0.5096
# Epoch 61/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.7193 - loss: 0.5864
# Epoch 62/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.7476 - loss: 0.5112
# Epoch 63/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.7363 - loss: 0.5262
# Epoch 64/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.7368 - loss: 0.5284
# Epoch 65/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7442 - loss: 0.5043
# Epoch 66/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.7364 - loss: 0.5288
# Epoch 67/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.7544 - loss: 0.4752
# Epoch 68/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.7406 - loss: 0.5212
# Epoch 69/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.7571 - loss: 0.4946
# Epoch 70/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.7149 - loss: 0.5418
# Epoch 71/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.7446 - loss: 0.5101
# Epoch 72/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.7398 - loss: 0.5156
# Epoch 73/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.7252 - loss: 0.5005
# Epoch 74/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.7611 - loss: 0.5063
# Epoch 75/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.7163 - loss: 0.5027
# Epoch 76/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - accuracy: 0.7365 - loss: 0.4988
# Epoch 77/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.7366 - loss: 0.5070
# Epoch 78/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.7570 - loss: 0.4967
# Epoch 79/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7500 - loss: 0.5385
# Epoch 80/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7364 - loss: 0.4926
# Epoch 81/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.7527 - loss: 0.4887
# Epoch 82/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.7390 - loss: 0.5029
# Epoch 83/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.7636 - loss: 0.4931
# Epoch 84/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.7493 - loss: 0.4892
# Epoch 85/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.7585 - loss: 0.4785
# Epoch 86/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7913 - loss: 0.4701
# Epoch 87/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.7558 - loss: 0.4981
# Epoch 88/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.7424 - loss: 0.5214
# Epoch 89/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.7600 - loss: 0.4918
# Epoch 90/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.7119 - loss: 0.5222
# Epoch 91/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.7529 - loss: 0.5138
# Epoch 92/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7776 - loss: 0.4836
# Epoch 93/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.7404 - loss: 0.5123
# Epoch 94/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7615 - loss: 0.4774
# Epoch 95/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.7330 - loss: 0.5038
# Epoch 96/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7346 - loss: 0.5326
# Epoch 97/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.7522 - loss: 0.5027
# Epoch 98/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7593 - loss: 0.4781
# Epoch 99/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.7594 - loss: 0.4827
# Epoch 100/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.7466 - loss: 0.4843
# Epoch 101/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7495 - loss: 0.4884
# Epoch 102/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.7698 - loss: 0.4580
# Epoch 103/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7462 - loss: 0.5013
# Epoch 104/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7667 - loss: 0.5130
# Epoch 105/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7879 - loss: 0.4696
# Epoch 106/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.7459 - loss: 0.4885
# Epoch 107/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.7724 - loss: 0.4699
# Epoch 108/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - accuracy: 0.7755 - loss: 0.4685
# Epoch 109/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.7675 - loss: 0.4618
# Epoch 110/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.7728 - loss: 0.4702
# Epoch 111/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.7499 - loss: 0.4823
# Epoch 112/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.7309 - loss: 0.5104
# Epoch 113/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.7521 - loss: 0.4873
# Epoch 114/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.7678 - loss: 0.4849
# Epoch 115/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.7880 - loss: 0.4554
# Epoch 116/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7285 - loss: 0.5104
# Epoch 117/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7607 - loss: 0.4879
# Epoch 118/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.7679 - loss: 0.5004
# Epoch 119/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.7591 - loss: 0.4962
# Epoch 120/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7823 - loss: 0.4585
# Epoch 121/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.7788 - loss: 0.4619
# Epoch 122/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.7977 - loss: 0.4511
# Epoch 123/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.7449 - loss: 0.4943
# Epoch 124/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.7619 - loss: 0.4891
# Epoch 125/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7427 - loss: 0.4995
# Epoch 126/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.7263 - loss: 0.4980
# Epoch 127/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.7559 - loss: 0.4631
# Epoch 128/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.7988 - loss: 0.4250
# Epoch 129/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.7490 - loss: 0.4720
# Epoch 130/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7531 - loss: 0.4776
# Epoch 131/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7590 - loss: 0.5034
# Epoch 132/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.7768 - loss: 0.4621
# Epoch 133/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.7545 - loss: 0.4903
# Epoch 134/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.7716 - loss: 0.4500
# Epoch 135/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.7971 - loss: 0.4302
# Epoch 136/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7690 - loss: 0.4780
# Epoch 137/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.7839 - loss: 0.4414
# Epoch 138/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.7662 - loss: 0.4807
# Epoch 139/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.7688 - loss: 0.4926
# Epoch 140/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7631 - loss: 0.4857
# Epoch 141/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.7925 - loss: 0.4376
# Epoch 142/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.7668 - loss: 0.4676
# Epoch 143/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7606 - loss: 0.4802
# Epoch 144/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.7549 - loss: 0.4777
# Epoch 145/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.7675 - loss: 0.4555
# Epoch 146/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.7857 - loss: 0.4408
# Epoch 147/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.7438 - loss: 0.4970
# Epoch 148/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.7377 - loss: 0.4806
# Epoch 149/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.7602 - loss: 0.4762
# Epoch 150/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.7599 - loss: 0.4664
# compile_metrics: 77.71%
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model to disk

# %% [markdown]
# ### 2. How to Load a Keras Model
# Your saved model can then be loaded later by calling the `load_model()` function and passing the filename. The function returns the model with the same architecture and weights.

# %%
# load and evaluate a saved model
import pandas as pd
from keras.models import load_model
# load model
model = load_model('./models/model.h5')
# summarize model.
model.summary()
# load dataset
dataset = pd.read_csv('./data/diabetes.csv')
dataset.columns = ['NTP', 'PGC','DBP','TSFT','2hSI','BMI','DPF','Age','OnDiab']
# split into input (X) and output (Y) variables
X = dataset.drop("OnDiab",axis=1)
Y = dataset["OnDiab"]
# evaluate the model
score = model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 12)             │           108 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 223 (896.00 B)
#  Trainable params: 221 (884.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
# compile_metrics: 77.71%

# %% [markdown]
# ### 3. Checkpoint Neural Network Model Improvements

# %% [markdown]
# Application checkpointing is a fault tolerance technique for long running processes. It is an approach where a snapshot of the state of the system is taken in case of system failure. If there is a problem, not all is lost. The checkpoint may be used directly, or used as the starting point for a new run, picking up where it left off. When training deep learning models, the checkpoint captures the weights of the model. These weights can be used to make predictions as-is, or used as the basis for ongoing training.
#
# The Keras library provides a checkpointing capability by a callback API. The `ModelCheckpoint` callback class allows you to define where to checkpoint the model weights, how the file should be named and under what circumstances to make a checkpoint of the model. The API allows you to specify which metric to monitor, such as loss or accuracy on the training or validation dataset. You can specify whether to look for an improvement in maximizing or minimizing the score. Finally, the filename that you use to store the weights can include variables like the epoch number or metric. The `ModelCheckpoint` instance can then be passed to the training process when calling the `fit()` function on the model.
#
# ##### Arguments
# - **filepath:** string, path to save the model file.
# - **monitor:** quantity to monitor.
# - **verbose:** verbosity mode, 0 or 1.
# - **save_best_only:** if save_best_only=True, the latest best model according to the quantity monitored will not be overwritten.
# - **save_weights_only:** if True, then only the model’s weights will be saved (model.save_weights(filepath)), else the full model is saved (model.save(filepath)).
# - **mode:** one of {auto, min, max}. If save_best_only=True, the decision to overwrite the current save file is made based on either the maximization or the minimization of the monitored quantity. For val_acc, this should be max, for val_loss this should be min, etc. In auto mode, the direction is automatically inferred from the name of the monitored quantity.
# - **period:** Interval (number of epochs) between checkpoints.

# %% [markdown]
# A good use of checkpointing is to output the model weights each time an improvement is observed during training. Checkpointing is set up to save the network weights only when there is an improvement in classification accuracy on the validation dataset `(monitor=’val accuracy’ and mode=’max’)`. The weights are stored in a file that includes the score in the filename `weights-improvement-epoch-val accuracy=.2f.hdf5`.

# %%
# Checkpoint the weights when validation accuracy improves
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
import pandas as pd
# load pima indians dataset
dataset = pd.read_csv('./data/diabetes.csv')
dataset.columns = ['NTP', 'PGC','DBP','TSFT','2hSI','BMI','DPF','Age','OnDiab']
# split into input (X) and output (Y) variables
X = dataset.drop("OnDiab",axis=1)
Y = dataset["OnDiab"]
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath="./models/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.keras"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,
save_best_only=True, mode='max')
callbacks_list = [checkpoint]
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list,
verbose=0)
# Out:
# /home/oem/Documents/github/magnimind_projects/magpenv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1: val_accuracy improved from -inf to 0.58661, saving model to ./models/weights-improvement-01-0.59.keras
#
# Epoch 2: val_accuracy improved from 0.58661 to 0.64173, saving model to ./models/weights-improvement-02-0.64.keras
#
# Epoch 3: val_accuracy improved from 0.64173 to 0.64961, saving model to ./models/weights-improvement-03-0.65.keras
#
# Epoch 4: val_accuracy improved from 0.64961 to 0.66929, saving model to ./models/weights-improvement-04-0.67.keras
#
# Epoch 5: val_accuracy did not improve from 0.66929
#
# Epoch 6: val_accuracy did not improve from 0.66929
#
# Epoch 7: val_accuracy did not improve from 0.66929
#
# Epoch 8: val_accuracy did not improve from 0.66929
#
# Epoch 9: val_accuracy did not improve from 0.66929
#
# Epoch 10: val_accuracy did not improve from 0.66929
#
# Epoch 11: val_accuracy did not improve from 0.66929
#
# Epoch 12: val_accuracy did not improve from 0.66929
#
# Epoch 13: val_accuracy did not improve from 0.66929
#
# Epoch 14: val_accuracy did not improve from 0.66929
#
# Epoch 15: val_accuracy did not improve from 0.66929
#
# Epoch 16: val_accuracy did not improve from 0.66929
#
# Epoch 17: val_accuracy did not improve from 0.66929
#
# Epoch 18: val_accuracy improved from 0.66929 to 0.67323, saving model to ./models/weights-improvement-18-0.67.keras
#
# Epoch 19: val_accuracy improved from 0.67323 to 0.67717, saving model to ./models/weights-improvement-19-0.68.keras
#
# Epoch 20: val_accuracy did not improve from 0.67717
#
# Epoch 21: val_accuracy did not improve from 0.67717
#
# Epoch 22: val_accuracy did not improve from 0.67717
#
# Epoch 23: val_accuracy did not improve from 0.67717
#
# Epoch 24: val_accuracy did not improve from 0.67717
#
# Epoch 25: val_accuracy did not improve from 0.67717
#
# Epoch 26: val_accuracy did not improve from 0.67717
#
# Epoch 27: val_accuracy did not improve from 0.67717
#
# Epoch 28: val_accuracy did not improve from 0.67717
#
# Epoch 29: val_accuracy did not improve from 0.67717
#
# Epoch 30: val_accuracy did not improve from 0.67717
#
# Epoch 31: val_accuracy did not improve from 0.67717
#
# Epoch 32: val_accuracy did not improve from 0.67717
#
# Epoch 33: val_accuracy did not improve from 0.67717
#
# Epoch 34: val_accuracy did not improve from 0.67717
#
# Epoch 35: val_accuracy did not improve from 0.67717
#
# Epoch 36: val_accuracy improved from 0.67717 to 0.68504, saving model to ./models/weights-improvement-36-0.69.keras
#
# Epoch 37: val_accuracy did not improve from 0.68504
#
# Epoch 38: val_accuracy did not improve from 0.68504
#
# Epoch 39: val_accuracy did not improve from 0.68504
#
# Epoch 40: val_accuracy did not improve from 0.68504
#
# Epoch 41: val_accuracy did not improve from 0.68504
#
# Epoch 42: val_accuracy did not improve from 0.68504
#
# Epoch 43: val_accuracy did not improve from 0.68504
#
# Epoch 44: val_accuracy did not improve from 0.68504
#
# Epoch 45: val_accuracy did not improve from 0.68504
#
# Epoch 46: val_accuracy did not improve from 0.68504
#
# Epoch 47: val_accuracy did not improve from 0.68504
#
# Epoch 48: val_accuracy did not improve from 0.68504
#
# Epoch 49: val_accuracy did not improve from 0.68504
#
# Epoch 50: val_accuracy did not improve from 0.68504
#
# Epoch 51: val_accuracy did not improve from 0.68504
#
# Epoch 52: val_accuracy did not improve from 0.68504
#
# Epoch 53: val_accuracy did not improve from 0.68504
#
# Epoch 54: val_accuracy did not improve from 0.68504
#
# Epoch 55: val_accuracy did not improve from 0.68504
#
# Epoch 56: val_accuracy did not improve from 0.68504
#
# Epoch 57: val_accuracy did not improve from 0.68504
#
# Epoch 58: val_accuracy did not improve from 0.68504
#
# Epoch 59: val_accuracy did not improve from 0.68504
#
# Epoch 60: val_accuracy did not improve from 0.68504
#
# Epoch 61: val_accuracy did not improve from 0.68504
#
# Epoch 62: val_accuracy did not improve from 0.68504
#
# Epoch 63: val_accuracy did not improve from 0.68504
#
# Epoch 64: val_accuracy did not improve from 0.68504
#
# Epoch 65: val_accuracy did not improve from 0.68504
#
# Epoch 66: val_accuracy did not improve from 0.68504
#
# Epoch 67: val_accuracy did not improve from 0.68504
#
# Epoch 68: val_accuracy did not improve from 0.68504
#
# Epoch 69: val_accuracy did not improve from 0.68504
#
# Epoch 70: val_accuracy did not improve from 0.68504
#
# Epoch 71: val_accuracy did not improve from 0.68504
#
# Epoch 72: val_accuracy did not improve from 0.68504
#
# Epoch 73: val_accuracy did not improve from 0.68504
#
# Epoch 74: val_accuracy did not improve from 0.68504
#
# Epoch 75: val_accuracy improved from 0.68504 to 0.68898, saving model to ./models/weights-improvement-75-0.69.keras
#
# Epoch 76: val_accuracy did not improve from 0.68898
#
# Epoch 77: val_accuracy did not improve from 0.68898
#
# Epoch 78: val_accuracy did not improve from 0.68898
#
# Epoch 79: val_accuracy did not improve from 0.68898
#
# Epoch 80: val_accuracy did not improve from 0.68898
#
# Epoch 81: val_accuracy did not improve from 0.68898
#
# Epoch 82: val_accuracy did not improve from 0.68898
#
# Epoch 83: val_accuracy did not improve from 0.68898
#
# Epoch 84: val_accuracy did not improve from 0.68898
#
# Epoch 85: val_accuracy improved from 0.68898 to 0.69685, saving model to ./models/weights-improvement-85-0.70.keras
#
# Epoch 86: val_accuracy did not improve from 0.69685
#
# Epoch 87: val_accuracy did not improve from 0.69685
#
# Epoch 88: val_accuracy did not improve from 0.69685
#
# Epoch 89: val_accuracy did not improve from 0.69685
#
# Epoch 90: val_accuracy did not improve from 0.69685
#
# Epoch 91: val_accuracy did not improve from 0.69685
#
# Epoch 92: val_accuracy did not improve from 0.69685
#
# Epoch 93: val_accuracy did not improve from 0.69685
#
# Epoch 94: val_accuracy did not improve from 0.69685
#
# Epoch 95: val_accuracy did not improve from 0.69685
#
# Epoch 96: val_accuracy did not improve from 0.69685
#
# Epoch 97: val_accuracy did not improve from 0.69685
#
# Epoch 98: val_accuracy did not improve from 0.69685
#
# Epoch 99: val_accuracy did not improve from 0.69685
#
# Epoch 100: val_accuracy did not improve from 0.69685
#
# Epoch 101: val_accuracy did not improve from 0.69685
#
# Epoch 102: val_accuracy did not improve from 0.69685
#
# Epoch 103: val_accuracy did not improve from 0.69685
#
# Epoch 104: val_accuracy did not improve from 0.69685
#
# Epoch 105: val_accuracy did not improve from 0.69685
#
# Epoch 106: val_accuracy did not improve from 0.69685
#
# Epoch 107: val_accuracy did not improve from 0.69685
#
# Epoch 108: val_accuracy did not improve from 0.69685
#
# Epoch 109: val_accuracy did not improve from 0.69685
#
# Epoch 110: val_accuracy did not improve from 0.69685
#
# Epoch 111: val_accuracy did not improve from 0.69685
#
# Epoch 112: val_accuracy improved from 0.69685 to 0.70079, saving model to ./models/weights-improvement-112-0.70.keras
#
# Epoch 113: val_accuracy did not improve from 0.70079
#
# Epoch 114: val_accuracy did not improve from 0.70079
#
# Epoch 115: val_accuracy did not improve from 0.70079
#
# Epoch 116: val_accuracy did not improve from 0.70079
#
# Epoch 117: val_accuracy did not improve from 0.70079
#
# Epoch 118: val_accuracy did not improve from 0.70079
#
# Epoch 119: val_accuracy did not improve from 0.70079
#
# Epoch 120: val_accuracy did not improve from 0.70079
#
# Epoch 121: val_accuracy did not improve from 0.70079
#
# Epoch 122: val_accuracy did not improve from 0.70079
#
# Epoch 123: val_accuracy did not improve from 0.70079
#
# Epoch 124: val_accuracy improved from 0.70079 to 0.70472, saving model to ./models/weights-improvement-124-0.70.keras
#
# Epoch 125: val_accuracy did not improve from 0.70472
#
# Epoch 126: val_accuracy did not improve from 0.70472
#
# Epoch 127: val_accuracy did not improve from 0.70472
#
# Epoch 128: val_accuracy did not improve from 0.70472
#
# Epoch 129: val_accuracy did not improve from 0.70472
#
# Epoch 130: val_accuracy did not improve from 0.70472
#
# Epoch 131: val_accuracy did not improve from 0.70472
#
# Epoch 132: val_accuracy did not improve from 0.70472
#
# Epoch 133: val_accuracy did not improve from 0.70472
#
# Epoch 134: val_accuracy did not improve from 0.70472
#
# Epoch 135: val_accuracy did not improve from 0.70472
#
# Epoch 136: val_accuracy did not improve from 0.70472
#
# Epoch 137: val_accuracy did not improve from 0.70472
#
# Epoch 138: val_accuracy did not improve from 0.70472
#
# Epoch 139: val_accuracy did not improve from 0.70472
#
# Epoch 140: val_accuracy did not improve from 0.70472
#
# Epoch 141: val_accuracy did not improve from 0.70472
#
# Epoch 142: val_accuracy did not improve from 0.70472
#
# Epoch 143: val_accuracy did not improve from 0.70472
#
# Epoch 144: val_accuracy did not improve from 0.70472
#
# Epoch 145: val_accuracy did not improve from 0.70472
#
# Epoch 146: val_accuracy did not improve from 0.70472
#
# Epoch 147: val_accuracy did not improve from 0.70472
#
# Epoch 148: val_accuracy did not improve from 0.70472
#
# Epoch 149: val_accuracy did not improve from 0.70472
#
# Epoch 150: val_accuracy did not improve from 0.70472

# %% [markdown]
# ### 4. Checkpoint Best Neural Network Model Only
# A simpler checkpoint strategy is to save the model weights to the same file, if and only if the validation accuracy improves. This can be done easily using the same code from above and changing the output filename to be fixed (not include score or epoch information). In this case, model weights are written to the file `weights.best.hdf5` only if the classification accuracy of the model on the validation dataset improves over the best seen so far.

# %%
# Checkpoint the weights for best model on validation accuracy
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
import pandas as pd
# load pima indians dataset
dataset = pd.read_csv('./data/diabetes.csv')
dataset.columns = ['NTP', 'PGC','DBP','TSFT','2hSI','BMI','DPF','Age','OnDiab']
# split into input (X) and output (Y) variables
X = dataset.drop("OnDiab",axis=1)
Y = dataset["OnDiab"]
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath="./models/weights.best.keras"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,
save_best_only=True, mode='max')
callbacks_list = [checkpoint]
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list,
verbose=0)
# Out:
# /home/oem/Documents/github/magnimind_projects/magpenv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1: val_accuracy improved from -inf to 0.53937, saving model to ./models/weights.best.keras
#
# Epoch 2: val_accuracy improved from 0.53937 to 0.62598, saving model to ./models/weights.best.keras
#
# Epoch 3: val_accuracy improved from 0.62598 to 0.64567, saving model to ./models/weights.best.keras
#
# Epoch 4: val_accuracy improved from 0.64567 to 0.66142, saving model to ./models/weights.best.keras
#
# Epoch 5: val_accuracy improved from 0.66142 to 0.66535, saving model to ./models/weights.best.keras
#
# Epoch 6: val_accuracy did not improve from 0.66535
#
# Epoch 7: val_accuracy did not improve from 0.66535
#
# Epoch 8: val_accuracy did not improve from 0.66535
#
# Epoch 9: val_accuracy did not improve from 0.66535
#
# Epoch 10: val_accuracy did not improve from 0.66535
#
# Epoch 11: val_accuracy did not improve from 0.66535
#
# Epoch 12: val_accuracy improved from 0.66535 to 0.66929, saving model to ./models/weights.best.keras
#
# Epoch 13: val_accuracy did not improve from 0.66929
#
# Epoch 14: val_accuracy did not improve from 0.66929
#
# Epoch 15: val_accuracy did not improve from 0.66929
#
# Epoch 16: val_accuracy did not improve from 0.66929
#
# Epoch 17: val_accuracy did not improve from 0.66929
#
# Epoch 18: val_accuracy did not improve from 0.66929
#
# Epoch 19: val_accuracy did not improve from 0.66929
#
# Epoch 20: val_accuracy did not improve from 0.66929
#
# Epoch 21: val_accuracy did not improve from 0.66929
#
# Epoch 22: val_accuracy did not improve from 0.66929
#
# Epoch 23: val_accuracy did not improve from 0.66929
#
# Epoch 24: val_accuracy did not improve from 0.66929
#
# Epoch 25: val_accuracy did not improve from 0.66929
#
# Epoch 26: val_accuracy did not improve from 0.66929
#
# Epoch 27: val_accuracy did not improve from 0.66929
#
# Epoch 28: val_accuracy did not improve from 0.66929
#
# Epoch 29: val_accuracy did not improve from 0.66929
#
# Epoch 30: val_accuracy did not improve from 0.66929
#
# Epoch 31: val_accuracy did not improve from 0.66929
#
# Epoch 32: val_accuracy did not improve from 0.66929
#
# Epoch 33: val_accuracy did not improve from 0.66929
#
# Epoch 34: val_accuracy did not improve from 0.66929
#
# Epoch 35: val_accuracy did not improve from 0.66929
#
# Epoch 36: val_accuracy did not improve from 0.66929
#
# Epoch 37: val_accuracy did not improve from 0.66929
#
# Epoch 38: val_accuracy did not improve from 0.66929
#
# Epoch 39: val_accuracy did not improve from 0.66929
#
# Epoch 40: val_accuracy did not improve from 0.66929
#
# Epoch 41: val_accuracy did not improve from 0.66929
#
# Epoch 42: val_accuracy did not improve from 0.66929
#
# Epoch 43: val_accuracy did not improve from 0.66929
#
# Epoch 44: val_accuracy did not improve from 0.66929
#
# Epoch 45: val_accuracy did not improve from 0.66929
#
# Epoch 46: val_accuracy did not improve from 0.66929
#
# Epoch 47: val_accuracy did not improve from 0.66929
#
# Epoch 48: val_accuracy did not improve from 0.66929
#
# Epoch 49: val_accuracy did not improve from 0.66929
#
# Epoch 50: val_accuracy did not improve from 0.66929
#
# Epoch 51: val_accuracy did not improve from 0.66929
#
# Epoch 52: val_accuracy did not improve from 0.66929
#
# Epoch 53: val_accuracy did not improve from 0.66929
#
# Epoch 54: val_accuracy did not improve from 0.66929
#
# Epoch 55: val_accuracy did not improve from 0.66929
#
# Epoch 56: val_accuracy did not improve from 0.66929
#
# Epoch 57: val_accuracy did not improve from 0.66929
#
# Epoch 58: val_accuracy did not improve from 0.66929
#
# Epoch 59: val_accuracy did not improve from 0.66929
#
# Epoch 60: val_accuracy did not improve from 0.66929
#
# Epoch 61: val_accuracy did not improve from 0.66929
#
# Epoch 62: val_accuracy did not improve from 0.66929
#
# Epoch 63: val_accuracy did not improve from 0.66929
#
# Epoch 64: val_accuracy did not improve from 0.66929
#
# Epoch 65: val_accuracy did not improve from 0.66929
#
# Epoch 66: val_accuracy did not improve from 0.66929
#
# Epoch 67: val_accuracy did not improve from 0.66929
#
# Epoch 68: val_accuracy did not improve from 0.66929
#
# Epoch 69: val_accuracy did not improve from 0.66929
#
# Epoch 70: val_accuracy did not improve from 0.66929
#
# Epoch 71: val_accuracy did not improve from 0.66929
#
# Epoch 72: val_accuracy did not improve from 0.66929
#
# Epoch 73: val_accuracy did not improve from 0.66929
#
# Epoch 74: val_accuracy did not improve from 0.66929
#
# Epoch 75: val_accuracy did not improve from 0.66929
#
# Epoch 76: val_accuracy did not improve from 0.66929
#
# Epoch 77: val_accuracy did not improve from 0.66929
#
# Epoch 78: val_accuracy did not improve from 0.66929
#
# Epoch 79: val_accuracy did not improve from 0.66929
#
# Epoch 80: val_accuracy did not improve from 0.66929
#
# Epoch 81: val_accuracy did not improve from 0.66929
#
# Epoch 82: val_accuracy did not improve from 0.66929
#
# Epoch 83: val_accuracy did not improve from 0.66929
#
# Epoch 84: val_accuracy did not improve from 0.66929
#
# Epoch 85: val_accuracy did not improve from 0.66929
#
# Epoch 86: val_accuracy did not improve from 0.66929
#
# Epoch 87: val_accuracy did not improve from 0.66929
#
# Epoch 88: val_accuracy did not improve from 0.66929
#
# Epoch 89: val_accuracy did not improve from 0.66929
#
# Epoch 90: val_accuracy did not improve from 0.66929
#
# Epoch 91: val_accuracy did not improve from 0.66929
#
# Epoch 92: val_accuracy did not improve from 0.66929
#
# Epoch 93: val_accuracy did not improve from 0.66929
#
# Epoch 94: val_accuracy did not improve from 0.66929
#
# Epoch 95: val_accuracy did not improve from 0.66929
#
# Epoch 96: val_accuracy did not improve from 0.66929
#
# Epoch 97: val_accuracy did not improve from 0.66929
#
# Epoch 98: val_accuracy did not improve from 0.66929
#
# Epoch 99: val_accuracy did not improve from 0.66929
#
# Epoch 100: val_accuracy did not improve from 0.66929
#
# Epoch 101: val_accuracy did not improve from 0.66929
#
# Epoch 102: val_accuracy did not improve from 0.66929
#
# Epoch 103: val_accuracy did not improve from 0.66929
#
# Epoch 104: val_accuracy did not improve from 0.66929
#
# Epoch 105: val_accuracy did not improve from 0.66929
#
# Epoch 106: val_accuracy did not improve from 0.66929
#
# Epoch 107: val_accuracy did not improve from 0.66929
#
# Epoch 108: val_accuracy did not improve from 0.66929
#
# Epoch 109: val_accuracy did not improve from 0.66929
#
# Epoch 110: val_accuracy did not improve from 0.66929
#
# Epoch 111: val_accuracy did not improve from 0.66929
#
# Epoch 112: val_accuracy did not improve from 0.66929
#
# Epoch 113: val_accuracy did not improve from 0.66929
#
# Epoch 114: val_accuracy did not improve from 0.66929
#
# Epoch 115: val_accuracy did not improve from 0.66929
#
# Epoch 116: val_accuracy did not improve from 0.66929
#
# Epoch 117: val_accuracy did not improve from 0.66929
#
# Epoch 118: val_accuracy did not improve from 0.66929
#
# Epoch 119: val_accuracy did not improve from 0.66929
#
# Epoch 120: val_accuracy did not improve from 0.66929
#
# Epoch 121: val_accuracy did not improve from 0.66929
#
# Epoch 122: val_accuracy did not improve from 0.66929
#
# Epoch 123: val_accuracy did not improve from 0.66929
#
# Epoch 124: val_accuracy did not improve from 0.66929
#
# Epoch 125: val_accuracy did not improve from 0.66929
#
# Epoch 126: val_accuracy did not improve from 0.66929
#
# Epoch 127: val_accuracy did not improve from 0.66929
#
# Epoch 128: val_accuracy did not improve from 0.66929
#
# Epoch 129: val_accuracy did not improve from 0.66929
#
# Epoch 130: val_accuracy did not improve from 0.66929
#
# Epoch 131: val_accuracy did not improve from 0.66929
#
# Epoch 132: val_accuracy did not improve from 0.66929
#
# Epoch 133: val_accuracy did not improve from 0.66929
#
# Epoch 134: val_accuracy did not improve from 0.66929
#
# Epoch 135: val_accuracy did not improve from 0.66929
#
# Epoch 136: val_accuracy did not improve from 0.66929
#
# Epoch 137: val_accuracy did not improve from 0.66929
#
# Epoch 138: val_accuracy did not improve from 0.66929
#
# Epoch 139: val_accuracy did not improve from 0.66929
#
# Epoch 140: val_accuracy did not improve from 0.66929
#
# Epoch 141: val_accuracy did not improve from 0.66929
#
# Epoch 142: val_accuracy did not improve from 0.66929
#
# Epoch 143: val_accuracy did not improve from 0.66929
#
# Epoch 144: val_accuracy did not improve from 0.66929
#
# Epoch 145: val_accuracy did not improve from 0.66929
#
# Epoch 146: val_accuracy did not improve from 0.66929
#
# Epoch 147: val_accuracy did not improve from 0.66929
#
# Epoch 148: val_accuracy did not improve from 0.66929
#
# Epoch 149: val_accuracy did not improve from 0.66929
#
# Epoch 150: val_accuracy did not improve from 0.66929

# %% [markdown]
# ### 5. Loading a Saved Neural Network Model

# %% [markdown]
# Now that you have seen how to checkpoint your deep learning models during training, you need to review how to load and use a checkpointed model. The checkpoint only includes the model weights. It assumes you know the network structure. In the example below, the model structure is known and the best weights are loaded from the previous experiment, stored in the working directory in the `weights.best.hdf5` file. The model is then used to make predictions on the entire dataset.

# %%
# How to load and use weights from a checkpoint
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# load weights
model.load_weights("./models/weights.best.keras")
# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print("Created model and loaded weights from file")
# load pima indians dataset
dataset = pd.read_csv('./data/diabetes.csv')
dataset.columns = ['NTP', 'PGC','DBP','TSFT','2hSI','BMI','DPF','Age','OnDiab']
# split into input (X) and output (Y) variables
X = dataset.drop("OnDiab",axis=1)
Y = dataset["OnDiab"]
# estimate accuracy on whole dataset using loaded weights
scores = model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# /home/oem/Documents/github/magnimind_projects/magpenv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Created model and loaded weights from file
# compile_metrics: 65.19%

# %% [markdown]
# ### 6. Visualize Model Training History in Keras

# %%
# Visualize training history
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
# load pima indians dataset
dataset = pd.read_csv('./data/diabetes.csv')
dataset.columns = ['NTP', 'PGC','DBP','TSFT','2hSI','BMI','DPF','Age','OnDiab']

# split into input (X) and output (Y) variables
X = dataset.drop("OnDiab",axis=1)
Y = dataset["OnDiab"]
# define model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
history = model.fit(X, Y, validation_split=0.33, epochs=500, batch_size=20, verbose=0)
# list all data in history
print(history.history.keys())
# Out:
# /home/oem/Documents/github/magnimind_projects/magpenv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
X.shape
# Out:
# (767, 8)
